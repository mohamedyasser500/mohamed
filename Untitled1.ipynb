# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('autompg1.csv',index_col=[0])

# %%
df.head()
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
#
#       origin                   car name
# mpg
# 18.0       1  chevrolet chevelle malibu
# 15.0       1          buick skylark 320
# 18.0       1         plymouth satellite
# 16.0       1              amc rebel sst
# 17.0       1                ford torino

# %%
df.dropna()
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
#       origin                   car name
# mpg
# ...

# %%
df.sort_index(level=['mpg'], ascending=False)
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 46.6          4          86.0        65.0    2110          17.9          80
# 44.6          4          91.0        67.0    1850          13.8          80
# 44.3          4          90.0        48.0    2085          21.7          80
# 44.0          4          97.0        52.0    2130          24.6          82
# 43.4          4          90.0        48.0    2335          23.7          80
# ...         ...           ...         ...     ...           ...         ...
# 11.0          8         350.0       180.0    3664          11.0          73
# 11.0          8         400.0       150.0    4997          14.0          73
# 10.0          8         307.0       200.0    4376          15.0          70
# 10.0          8         360.0       215.0    4615          14.0          70
# 9.0           8         304.0       193.0    4732          18.5          70
#
#       origin              car name
# mpg
# ...

# %%
df['horsepower'].mean()
# Out:
# 104.46938775510205

# %%
df.columns
# Out:
# Index(['cylinders', 'displacement', 'horsepower', 'weight', 'acceleration',
#        'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df['watt']= df['horsepower'] *746

# %%
df
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
#       origin                   car name      watt
# ...

# %%
df['Kilowatt']= df['watt']/1000

# %%
df
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
# ...

# %%
df['How many lamps can this engine light up']= df['watt'] /100

# %%
df
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
# ...

# %%
df.sort_index(level=['mpg'], ascending=False)
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 46.6          4          86.0        65.0    2110          17.9          80
# 44.6          4          91.0        67.0    1850          13.8          80
# 44.3          4          90.0        48.0    2085          21.7          80
# 44.0          4          97.0        52.0    2130          24.6          82
# 43.4          4          90.0        48.0    2335          23.7          80
# ...         ...           ...         ...     ...           ...         ...
# 11.0          8         350.0       180.0    3664          11.0          73
# 11.0          8         400.0       150.0    4997          14.0          73
# 10.0          8         307.0       200.0    4376          15.0          70
# 10.0          8         360.0       215.0    4615          14.0          70
# 9.0           8         304.0       193.0    4732          18.5          70
#
# ...

# %%
df['Effiecncy']= df['acceleration'] / df['horsepower']

# %%
df
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
# ...

# %%
df.sort_values('Effiecncy' , ascending=False )
df.dropna()
# Out:
#       cylinders  displacement  horsepower  weight  acceleration  model year  \
# mpg
# 18.0          8         307.0       130.0    3504          12.0          70
# 15.0          8         350.0       165.0    3693          11.5          70
# 18.0          8         318.0       150.0    3436          11.0          70
# 16.0          8         304.0       150.0    3433          12.0          70
# 17.0          8         302.0       140.0    3449          10.5          70
# ...         ...           ...         ...     ...           ...         ...
# 27.0          4         140.0        86.0    2790          15.6          82
# 44.0          4          97.0        52.0    2130          24.6          82
# 32.0          4         135.0        84.0    2295          11.6          82
# 28.0          4         120.0        79.0    2625          18.6          82
# 31.0          4         119.0        82.0    2720          19.4          82
#
# ...
